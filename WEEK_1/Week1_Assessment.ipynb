# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Projects/Week1_Assessment/combined_dataset.csv")

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
print("Colums in Data Frame : \n ",df.columns)
# Out:
# Colums in Data Frame :
#   Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
print("No.of rows, columns in DataFrame :" ,df.shape)
# Out:
# No.of rows, columns in DataFrame : (1000, 24)

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df["discount"] = df["discount"].fillna(0)

# %%
df["what_customers_said"] = df["what_customers_said"].fillna("No Review")

# %%
df["seller_information"] = df["seller_information"].fillna("Not Available")

# %%
df["variations"] = df["variations"].fillna("No Variations")

# %%
df['seller_name']=df['seller_name'].fillna('Unknown Seller')

# %%
df.drop("videos", axis=1, inplace=True)

# %%
print("After handling missing values\n",df.isnull().sum())
# Out:
# After handling missing values
#  product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
# Perform basic operations (filter rows, select columns)
print("Products with discount > 80")
df[df['discount'] > 80]
# Out:
# Products with discount > 80
#      product_id                                       title  \
# 18     22409156                                     Kastner
# 21      1728397                                     Mactree
# 176    13382036                                       plusS
# 213    10125241                                   KARATCART
# 227    13401002                         Adwitiya Collection
# 228    13340876                                  Kord Store
# 229    12930940  TOKYO TALKIES X rubans FASHION ACCESSORIES
# 236    22593680                                      ZENEME
# 356    19837040                                   High Star
# 357    19837008                                   High Star
# 447    12509548                                       Ishin
# 491    17359602                                Swiss Design
# 507    15294314                               Zaveri Pearls
# 508    16254760                               Zaveri Pearls
# ...

# %%
print("Products with rating > 4")
df[df["rating"] > 4]
# Out:
# Products with rating > 4
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 991     2466414       Daniel Klein
# 992    11791782              CASIO
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ...

# %%
df1=df[['product_id','title','category','initial_price','discount','final_price']]
print(df1)
# Out:
#      product_id           title   category  initial_price  discount  \
# 0       8376765     Lino Perros  backpacks           3995      58.0
# 1       9136281  Tommy Hilfiger  backpacks           2899      35.0
# 2      17633752           Lavie  backpacks           2999      65.0
# 3       1376949          F Gear  backpacks           1675      52.0
# 4      13939916       MYTRIDENT  bath-robe           2899      17.0
# ..          ...             ...        ...            ...       ...
# 995    13698258           KREDO    watches          11890      50.0
# 996    16896006           GUESS    watches           8900      45.0
# 997     1708108        GIORDANO    watches           7950      50.0
# 998    19280114        Fastrack    watches           3295      20.0
# 999    18601682         BOLDFIT  yoga-mats            699      31.0
#
#       final_price
# 0     "₹3,995.00"
# 1     "₹2,899.00"
# 2     "₹2,999.00"
# 3     "₹1,675.00"
# 4     "₹2,899.00"
# ..            ...
# ...

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1000, 23)

# %%
#.Create a derived column (total_amount = price * quantity)

# %%
df["total_amount"] = df["final_price"] * 1 # cause quantity column is not present in the dataset

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df.to_csv('Cleaned_Combined_dataset.csv', index=False)
